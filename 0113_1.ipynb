# %% [markdown]
# <a href="https://colab.research.google.com/github/t8101349/Colab-/blob/master/0113_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Pandas
1. 從無生有一個表格
    Step1. 你要準備一個空的List
    Step2. 把妳的每一筆資料準備成一個Dict, 放進List裡
    Step3. 轉成DataFrame儲存

    [danmu, danmu,..]

# %%
import urllib.request as req
import bs4 as bs
# Step 0.
import pandas as pd

# Step1. 準備一個空的List
table = []
page = 1
while True:
    print("頁數:", page)
    url = "https://tabelog.com/tw/tokyo/rstLst/{}/?SrtT=rt".format(page)
    page = page + 1
    response = req.urlopen(url)
    html = bs.BeautifulSoup(response)

    r_list = html.find_all("div", {"class":"list-rst__body"})
    if len(r_list) == 0:
        break

    for r in r_list:
        en_name = r.find("a", {"class":"list-rst__rst-name-target"})
        en_name_href = en_name["href"]
        en_name_text = en_name.text
        area = r.find("div", {"class":"list-rst__area-genre"})
        area_text = area.text.strip()
        intro = r.find("p", {"class":"list-rst__pr-title"})
        if intro == None:
            intro_text = "無"
        else:
            intro_text = intro.text.strip()
        rating = r.find("span", {"class":"c-rating__val"})
        rating_text = rating.text
        prices = r.find_all("span", {"class":"c-rating-v3__val"})
        dinner_price = prices[0].text
        lunch_price = prices[1].text
        holiday = r.find("span", {"class":"list-rst__holiday-text"})
        holiday_text = holiday.text

        print(rating_text)
        print(en_name_text)
        print(en_name_href)
        print(area_text)
        print(intro_text)
        print(holiday_text)
        print("晚間價錢:", dinner_price, "午間價錢:", lunch_price)
        print("-" * 30)

        # Step2. 每一筆資料就是一個字典
        data = {
            "name(en)": en_name_text,
            "url": en_name_href,
            "area": area_text,
            "intro": intro_text,
            "rating": rating_text,
            "dinner_price": dinner_price,
            "lunch_price": lunch_price,
            "holidays": holiday_text
        }
        table.append(data)

# Step3. 轉成DataFrame儲存
df = pd.DataFrame(table,
          columns=["name(en)", "url", "area", "intro","dinner_price","lunch_price","holidays", "rating"])
df.to_csv("tabelog.csv", encoding="utf-8")
# Out:
# 串流輸出內容已截斷至最後 5000 行。
# 3.78
# SIROTAE
# https://tabelog.com/tw/tokyo/A1308/A130801/13002850/
# 赤坂見附車站 / 蛋糕, 咖啡店, 喫茶店
# 無
# 星期一、星期日
# 晚間價錢: - 午間價錢: JPY 1,000～JPY 1,999
# ------------------------------
# 頁數: 30
# 3.78
# Naniwaya Sohonten
# https://tabelog.com/tw/tokyo/A1307/A130702/13002775/
# 麻布十番車站 / 日式甜點店, 鯛魚燒・大判燒, 炒麵
# 無
# 星期二、星期三
# 晚間價錢: - 午間價錢: ～JPY 999
# ------------------------------
# 3.78
# Niboshi Tsukemen Miyamoto
# https://tabelog.com/tw/tokyo/A1315/A131503/13180862/
# 蒲田車站 / 沾麵, 拉麵
# [從蒲田車站步行4分鐘]獨一無二的拉麵！ ！
# 星期日
# 晚間價錢: JPY 1,000～JPY 1,999 午間價錢: JPY 1,000～JPY 1,999
# ------------------------------
# 3.78
# Tsukesoba Kanda Katsumoto
# https://tabelog.com/tw/tokyo/A1310/A131003/13192433/
# 神保町車站 / 沾麵, 拉麵
# 無
# 星期日
# 晚間價錢: - 午間價錢: ～JPY 999
# ------------------------------
# 3.78
# Mentokoro Ginzasa
# https://tabelog.com/tw/tokyo/A1301/A130103/13119563/
# 築地市場車站 / 拉麵, 沾麵
# 無
# 星期日、節假日
# 晚間價錢: JPY 1,000～JPY 1,999 午間價錢: JPY 1,000～JPY 1,999
# ------------------------------
# ...

# %% [markdown]
# Pandas基本操作
# 直的叫行(column) 列(row)
#
# 1. 取column
# 2. 取row
# 3. filter
# 4. apply
# 5. 無中生有一個表格(上面)

# %%
import pandas as pd
practice = pd.DataFrame([
    [1,2,3],
    [4,5,6],
    [7,8,9]
  ],
  index = ['x','y','z'],
  columns = ['a','b','c'])
practice
# Out:
#    a  b  c
# x  1  2  3
# y  4  5  6
# z  7  8  9

# %%
# 取行: 字典
practice["a"]
practice[["a", "c"]]

# %%
print(type(practice['a']))
print(type(practice[['a','c']]))
#pandas 兩種型態:
#1.Series: 只有行或列,1D
#2.DataFrame: 表格,2D
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %%
# 取列 1. 看他實際第幾列(iloc): list, 把0..2當key  2. 看列標籤(loc): 字典, 列標籤當key
# 專屬值
practice.loc["y"]
#practice.iloc[1]
# Out:
# a    4
# b    5
# c    6
# x    1
# Name: y, dtype: int64

# %%
practice.iloc[1]
# Out:
# a    4
# b    5
# c    6
# x    1
# Name: y, dtype: int64

# %%
# 過濾(filter)原理: 把跟妳列的筆數一樣多的True False帶給她[]
# 對到True的就會留下, 對到False的就會丟掉
fil = [True, False, True]
practice[fil]

# %%
df['rating']
# Out:
# 0       4.67
# 1       4.63
# 2       4.61
# 3       4.61
# 4       4.59
#         ...
# 1195    3.72
# 1196    3.72
# 1197    3.72
# 1198    3.72
# 1199    3.72
# Name: rating, Length: 1200, dtype: object

# %%
df['rating'] = df['rating'].astype('float')

# %%
df['rating']>=4.0
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1195    False
# 1196    False
# 1197    False
# 1198    False
# 1199    False
# Name: rating, Length: 1200, dtype: bool

# %%
filter = df['rating']>=4.0
df[filter]
# Out:
#                           name(en)  \
# 0    Nihonbashi Kakigaracho Sugita
# 1                Shimbashi Hoshino
# 2             Higashiazabu Amamoto
# 3                              Aka
# 4                       Sushi Arai
# ..                             ...
# 201             SATO Brian Hon Ten
# 202                     Tomidokoro
# 203           L'Atelier à Ma Façon
# 204                        Kalpasi
# 205                         Ara Ki
#
#                                                    url  \
# 0    https://tabelog.com/tw/tokyo/A1302/A130204/130...
# 1    https://tabelog.com/tw/tokyo/A1314/A131401/131...
# 2    https://tabelog.com/tw/tokyo/A1314/A131401/131...
# 3    https://tabelog.com/tw/tokyo/A1302/A130202/132...
# 4    https://tabelog.com/tw/tokyo/A1301/A130101/131...
# ..                                                 ...
# 201  https://tabelog.com/tw/tokyo/A1319/A131905/131...
# 202  https://tabelog.com/tw/tokyo/A1314/A131401/132...
# ...

# %%
df["rating"] = df["rating"].astype("float")
# fil = df["rating"] >= 4.0
# df[fil]
# 妳可以做條件組合 and->& or->|
fil = (df["rating"] <= 4.1) & (df["rating"] >= 3.8)
df[fil]
# Out:
#                          name(en)  \
# 148                  HATSUNEZUSHI
# 149                  Tori Chataro
# 150              Akasaka Kitafuku
# 151                          unis
# 152  YORONIKU TOKYO AZABUDAIHILLS
# ..                            ...
# 525                         Think
# 526                  Four Seasons
# 527         Sushi Saitou Azabudai
# 528                 Sushi Imamura
# 529                            DK
#
#                                                    url                   area  \
# 148  https://tabelog.com/tw/tokyo/A1315/A131503/130...              蒲田車站 / 壽司
# 149  https://tabelog.com/tw/tokyo/A1303/A130301/131...            澀谷車站 / 烤雞肉串
# 150  https://tabelog.com/tw/tokyo/A1308/A130801/131...              赤坂車站 / 螃蟹
# 151  https://tabelog.com/tw/tokyo/A1308/A130802/132...  虎之門Hills車站 / 法式料理, 創新
# 152  https://tabelog.com/tw/tokyo/A1307/A130701/132...          六本木一丁目車站 / 燒肉
# ..                                                 ...                    ...
# ...

# %%
fil = (3.8 <= df["rating"] <= 4.1)
df[fil]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-7d3b01606b27> in <cell line: 1>()
# ----> 1 fil = (3.8 <= df["rating"] <= 4.1)
#       2 df[fil]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __nonzero__(self)
#    1575     @final
#    1576     def __nonzero__(self) -> NoReturn:
# -> 1577         raise ValueError(
#    1578             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1579             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
fil_rat = df["rating"] >= 4.1
fil_loc1 = df["area"].str.contains("澀谷")
fil_loc2 = df["area"].str.contains("蒲田")
df[fil_rat & (fil_loc1 | fil_loc2)]
# Out:
#          name(en)                                                url  \
# 148  HATSUNEZUSHI  https://tabelog.com/tw/tokyo/A1315/A131503/130...
# 149  Tori Chataro  https://tabelog.com/tw/tokyo/A1303/A130301/131...
#
#             area                intro  rating
# 148    蒲田車站 / 壽司  充滿渾身解數和氣魄的超乎想象的握壽司。     4.1
# 149  澀谷車站 / 烤雞肉串                    無     4.1

# %%
table = []
for h in df['holidays']:
  data = {
      '星期一':True,
      '星期二':True,
      '星期三':True,
      '星期四':True,
      '星期五':True,
      '星期六':True,
      '星期日':True,
      '節假日':True
  }
  for d in data.keys():
    if d in h:
      data[d] = False

  table.append(data)
holidays = pd.DataFrame(table)
holidays
# Out:
#        星期一   星期二    星期三   星期四   星期五   星期六    星期日    節假日
# 0     True  True   True  True  True  True   True   True
# 1     True  True   True  True  True  True  False  False
# 2     True  True  False  True  True  True  False   True
# 3     True  True   True  True  True  True   True   True
# 4     True  True  False  True  True  True   True   True
# ...    ...   ...    ...   ...   ...   ...    ...    ...
# 1195  True  True   True  True  True  True   True   True
# 1196  True  True   True  True  True  True  False  False
# 1197  True  True   True  True  True  True   True   True
# 1198  True  True   True  True  True  True   True   True
# 1199  True  True   True  True  True  True  False  False
#
# [1200 rows x 8 columns]

# %%
total = pd.concat([df, holidays], axis=1)
 # 過濾: 禮拜日有開, 要大於3.5
fil = (total["星期日"] == True) & (total["rating"].astype("float") >= 3.7)
total[fil]
# Out:
#                                             name(en)  \
# 0                      Nihonbashi Kakigaracho Sugita
# 3                                                Aka
# 4                                         Sushi Arai
# 7                                                 Ao
# 8                                         PELLEGRINO
# ...                                              ...
# 1193                                        Hasegawa
# 1194           Zopf Curry Pan Senmon Ten Gransta Ten
# 1195                           Ramen Jiro Meguro Ten
# 1197                    Dame na Rinjin Ningyocho Ten
# 1198  DANDELION CHOCOLATE Fakutori Ando Kafe Kuramae
#
#                                                     url  \
# 0     https://tabelog.com/tw/tokyo/A1302/A130204/130...
# 3     https://tabelog.com/tw/tokyo/A1302/A130202/132...
# 4     https://tabelog.com/tw/tokyo/A1301/A130101/131...
# 7     https://tabelog.com/tw/tokyo/A1307/A130701/132...
# ...

# %%
table = []
for din in df['dinner_price']:
  data = {
      'dinner_price_upperbound':False

  }
  data['dinner_price_upperbound'] = din.split('JPY')[-1]

  table.append(data)
dinner_price = pd.DataFrame(table)
dinner_price
# Out:
#      dinner_price_upperbound
# 0                     49,999
# 1                     59,999
# 2                     49,999
# 3                     79,999
# 4                     59,999
# ...                      ...
# 1195                     999
# 1196                   2,999
# 1197                   1,999
# 1198                       -
# 1199                     999
#
# [1200 rows x 1 columns]

# %%
table = []
for lun in df['lunch_price']:
  data = {
      'lunch_price_upperbound':False

  }
  data['lunch_price_upperbound'] = lun.split('JPY')[-1]


  table.append(data)
lunch_price = pd.DataFrame(table)
lunch_price
# Out:
#      lunch_price_upperbound
# 0                    49,999
# 1                         -
# 2                         -
# 3                         -
# 4                    59,999
# ...                     ...
# 1195                    999
# 1196                  1,999
# 1197                  1,999
# 1198                  1,999
# 1199                    999
#
# [1200 rows x 1 columns]

# %%
total2 = pd.concat([total, dinner_price], axis=1)
total3 = pd.concat([total2, lunch_price], axis=1)
total3
# Out:
#                                             name(en)  \
# 0                      Nihonbashi Kakigaracho Sugita
# 1                                  Shimbashi Hoshino
# 2                               Higashiazabu Amamoto
# 3                                                Aka
# 4                                         Sushi Arai
# ...                                              ...
# 1195                           Ramen Jiro Meguro Ten
# 1196                               Tonkatsu Masamune
# 1197                    Dame na Rinjin Ningyocho Ten
# 1198  DANDELION CHOCOLATE Fakutori Ando Kafe Kuramae
# 1199                              Kita Ootsuka Ramen
#
#                                                     url  \
# 0     https://tabelog.com/tw/tokyo/A1302/A130204/130...
# 1     https://tabelog.com/tw/tokyo/A1314/A131401/131...
# 2     https://tabelog.com/tw/tokyo/A1314/A131401/131...
# 3     https://tabelog.com/tw/tokyo/A1302/A130202/132...
# ...

# %%
# Series.apply(轉換方式)
# 原有值->轉換方式->新值
# 轉換方式是一個函式(錦囊),不加括號()
df['rating'].astype('float')
df["rating"].apply(round)
# Out:
# 0       4.67
# 1       4.63
# 2       4.61
# 3       4.61
# 4       4.59
#         ...
# 1195    3.72
# 1196    3.72
# 1197    3.72
# 1198    3.72
# 1199    3.72
# Name: rating, Length: 1200, dtype: float64

# %%
# 函式是形態(?????)
# 以前: 我跟妳說每個功能都要加小括號, 就算沒帶入參數也要加
# Everything is an object: 每個東西都是有形態的, 每個形態都有這個形態可以做的操作
# list 操作:[0] [-1]  dict 操作: [key]
# round(4.2)???
# round是一個形態 (4.2)是這個形態的操作
# round是步驟集合形態  (4.2)才是真的把這個步驟執行完得到節果
# 刷牙步驟        開始刷
# 函式形態: 還沒被打開的錦囊
# 加小括號: 把錦囊打開, 執行並得到結果
b = round
b(5.5)

import math
def func(state):
    if state == 0:
        return math.gcd
    else:
        return math.lcm
        # 可以傳出函式型態(錦囊)-->之後再打開

func(1)(6, 9)
# Out:
# 18

# %%
import pandas as pd
df = df.read_csv("tabelog.csv", encoding="utf-8")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-71-f0cffbf78241> in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 df = df.read_csv("tabelog.csv", encoding="utf-8")
#       3 def func(s):
#       4   real_area = s.split("/")[0]
#       5   return real_area
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'read_csv'

# %%
def func(s):
  real_area = s.split("/")[0]
  return real_area.strip()
df["area"] = df["area"].apply(func)
df
# Out:
#                                             name(en)  \
# 0                      Nihonbashi Kakigaracho Sugita
# 1                                  Shimbashi Hoshino
# 2                               Higashiazabu Amamoto
# 3                                                Aka
# 4                                         Sushi Arai
# ...                                              ...
# 1195                           Ramen Jiro Meguro Ten
# 1196                               Tonkatsu Masamune
# 1197                    Dame na Rinjin Ningyocho Ten
# 1198  DANDELION CHOCOLATE Fakutori Ando Kafe Kuramae
# 1199                              Kita Ootsuka Ramen
#
#                                                     url     area  \
# 0     https://tabelog.com/tw/tokyo/A1302/A130204/130...   水天宮前車站
# 1     https://tabelog.com/tw/tokyo/A1314/A131401/131...    御成門車站
# 2     https://tabelog.com/tw/tokyo/A1314/A131401/131...    赤羽橋車站
# ...

# %%
df["area"].value_counts()
# Out:
# area
# 銀座車站        50
# 六本木車站       37
# 廣尾車站        35
# 麻布十番車站      27
# 惠比壽車站       25
#             ..
# 千石車站         1
# 板橋區政府前車站     1
# 石神井公園車站      1
# 鶴川車站         1
# 大塚車站前車站      1
# Name: count, Length: 296, dtype: int64

# %%
df[df["area"].str.contains('廣尾車站')].shape
df[df["area"].str.contains('廣尾車站')]
# Out:
#                         name(en)  \
# 8                     PELLEGRINO
# 12                       Sazenka
# 24                   Gourmandise
# 42               Hasegawa Minoru
# 46                   Sushi Akira
# 98      Minami Aoyama Nana Chome
# 114                  Kaoru HIROO
# 133      4000 Chinese Restaurant
# 162                   sushi riku
# 221                  Torisawa 22
# 287                           K+
# 290                    Sushi Zai
# 301                    Ushimatsu
# 304                      BOTTEGA
# 309                         Towa
# 339        IL TEATRINO DA SALONE
# 377            Restaurant MANOIR
# 379           Restaurant ALADDIN
# 450                    Toku Yama
# 451                  Sushi Yuuki
# 475           Kasumicho Yamagami
# 523                      incanto
# 573                  Alternative
# 643         A New Shohei Shimono
# 777   Restaurant Hiramatsu Hiroo
# 799                     Kusabira
# 808                  Sushi Oochi
# ...

# %%
total3['area'] = total3['area'].apply(func)
total3
# Out:
#                                             name(en)  \
# 0                      Nihonbashi Kakigaracho Sugita
# 1                                  Shimbashi Hoshino
# 2                               Higashiazabu Amamoto
# 3                                                Aka
# 4                                         Sushi Arai
# ...                                              ...
# 1195                           Ramen Jiro Meguro Ten
# 1196                               Tonkatsu Masamune
# 1197                    Dame na Rinjin Ningyocho Ten
# 1198  DANDELION CHOCOLATE Fakutori Ando Kafe Kuramae
# 1199                              Kita Ootsuka Ramen
#
#                                                     url     area  \
# 0     https://tabelog.com/tw/tokyo/A1302/A130204/130...   水天宮前車站
# 1     https://tabelog.com/tw/tokyo/A1314/A131401/131...    御成門車站
# 2     https://tabelog.com/tw/tokyo/A1314/A131401/131...    赤羽橋車站
# ...

# %%
def func2(s, name):
  if name in s:
    return True
  else:
    return False
def func3(s, score):
  s0 = float(s)
  if s0 >= score:
    return True
  else:
    return False

fil = total3['area'].apply(func2, args= ['惠比壽'])  #.str.contains('')
fil2 = total3['rating'].apply(func3, args= [3.9])
total3[fil & fil2]
# Out:
#                                     name(en)  \
# 39                  Gastronomy Joel Robuchon
# 51                            Ebisu Yoroniku
# 58                                      WASA
# 136                                     Eiki
# 271                               Ebisu Endo
# 288                                LESS Labo
# 308  LESS by Gabriele Riva & Kanako Sakakura
#
#                                                    url   area  \
# 39   https://tabelog.com/tw/tokyo/A1303/A130302/130...  惠比壽車站
# 51   https://tabelog.com/tw/tokyo/A1303/A130302/132...  惠比壽車站
# 58   https://tabelog.com/tw/tokyo/A1303/A130302/132...  惠比壽車站
# 136  https://tabelog.com/tw/tokyo/A1303/A130302/132...  惠比壽車站
# 271  https://tabelog.com/tw/tokyo/A1303/A130302/132...  惠比壽車站
# 288  https://tabelog.com/tw/tokyo/A1303/A130302/132...  惠比壽車站
# 308  https://tabelog.com/tw/tokyo/A1303/A130302/132...  惠比壽車站
#
#                                 intro           dinner_price  \
# ...

# %%
def func(s, name):
    if name in s:
        return True
    else:
        return False
fil = df["area"].apply(func, args=["銀座車站"])
df[fil]
# Out:
#                                             name(en)  \
# 4                                         Sushi Arai
# 11                                            Sawada
# 25                                           L'OSIER
# 38                                     Nikuya Tanaka
# 55                                          ESqUISSE
# ...                                              ...
# 1151                           Le jardin des saveurs
# 1155                                    LITTLE SMITH
# 1157                                     Ginza Kazen
# 1161                           TAKAHASHIYA Ginza Ten
# 1179  Kobe Gyuu Rogama Sumiyaki Steak Ginza Ichimiya
#
#                                                     url   area  \
# 4     https://tabelog.com/tw/tokyo/A1301/A130101/131...   銀座車站
# 11    https://tabelog.com/tw/tokyo/A1301/A130101/130...   銀座車站
# 25    https://tabelog.com/tw/tokyo/A1301/A130101/130...   銀座車站
# 38    https://tabelog.com/tw/tokyo/A1301/A130101/132...   銀座車站
# ...

# %%
df["area"].value_counts()
df[df["area"] == "東銀座車站"]
# Out:
#                                             name(en)  \
# 112                                      Sushi Ikkou
# 213                                     Sushi Takeru
# 243                                         Tokyo En
# 311                                 Kobikicho Tomoki
# 385                                     BAR Shusendo
# 453                                    Ginza Hachigo
# 634                                      Ginza Inaba
# 650                      Mugi to Olive Ginza Hon Ten
# 703                                         Tokihami
# 801                                      Fugu Fukuji
# 802                                         Hiroyuki
# 837                                   Ginza Ukai Tei
# 908                                       Ginza Kudo
# 1108                                     Soba Sasuga
# 1151                           Le jardin des saveurs
# 1161                           TAKAHASHIYA Ginza Ten
# 1179  Kobe Gyuu Rogama Sumiyaki Steak Ginza Ichimiya
#
# ...

# %%
df[df["area"].str.contains("銀座")]
# Out:
#                                             name(en)  \
# 4                                         Sushi Arai
# 9                                    Ginza Shinohara
# 11                                            Sawada
# 25                                           L'OSIER
# 34                                      Ginza Ooishi
# ...                                              ...
# 1151                           Le jardin des saveurs
# 1155                                    LITTLE SMITH
# 1157                                     Ginza Kazen
# 1161                           TAKAHASHIYA Ginza Ten
# 1179  Kobe Gyuu Rogama Sumiyaki Steak Ginza Ichimiya
#
#                                                     url     area  \
# 4     https://tabelog.com/tw/tokyo/A1301/A130101/131...     銀座車站
# 9     https://tabelog.com/tw/tokyo/A1301/A130101/132...  銀座一丁目車站
# 11    https://tabelog.com/tw/tokyo/A1301/A130101/130...     銀座車站
# ...

# %%
fil1 = df["area"]=="銀座車站"
fil2 = df["area"]=="惠比壽車站"
fil3 = df["rating"].apply(func3, args=[4.0])
df[(fil1|fil2) & fil3]
# Out:
#                      name(en)  \
# 4                  Sushi Arai
# 11                     Sawada
# 25                    L'OSIER
# 38              Nikuya Tanaka
# 39   Gastronomy Joel Robuchon
# 51             Ebisu Yoroniku
# 55                   ESqUISSE
# 58                       WASA
# 68               Sushi Suzuki
# 96                   ZURRIOLA
# 105         USHIGORO S. GINZA
# 120                     subin
# 131                   L'ecrin
# 134      Restaurant Raffinage
# 136                      Eiki
# 141             Kiyota Hanare
# 143               Azabu Muroi
# 159               Sushi Saeki
# 161              GINZA JOTAKI
# 170             Tempura Kondo
# 189            Ginza Fujiyama
#
#                                                    url   area  \
# 4    https://tabelog.com/tw/tokyo/A1301/A130101/131...   銀座車站
# 11   https://tabelog.com/tw/tokyo/A1301/A130101/130...   銀座車站
# 25   https://tabelog.com/tw/tokyo/A1301/A130101/130...   銀座車站
# ...

# %%
jieba

# %% [markdown]
# #Jieba
# 抓出關鍵詞
#
# 1.拼音型: 英文  字母->詞彙->片語(phrase)
#
# 2.造字(東方)型: 中文 字->詞
#
# 分詞: 我喜歡吃甜食 -> 我/喜歡/吃/甜食
#
# 哪個詞彙在整段話裡最重要?
#
# 1.次數高
#
# 2.不常出現的字詞
#
# 3.強調字
#
# 詞彙重要度
# TF-IDF = 出現次數 * log(1/常用頻率)
#
#
# Jieba函式庫:
# 1.預先統計常用程度
# 2.分詞: 利用詞彙庫做初步劃分
