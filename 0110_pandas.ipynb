# %% [markdown]
# <a href="https://colab.research.google.com/github/t8101349/Colab-/blob/master/0110_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#Colab資料夾設定方法
#!pip install google.colab #如未安裝取消註解後執行
import os

from google.colab import drive
drive.mount('/content/drive')

##出現提示欄進行授權

os.chdir('/content/drive/My Drive/{你的google雲端硬碟資料夾位址}') #切換該目錄
os.listdir() #確認目錄內容
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-4-d5df0069828e> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     135   )
#     136   if ephemeral:
# --> 137     _message.blocking_request(
#     138         'request_auth',
#     139         request={'authType': 'dfs_ephemeral'},
#
# ...

# %%
data = pd.read_excel('/content/sample_data/R公司_人員資料.xlsx')
data.head
# Out:
# <bound method NDFrame.head of       員工編號(EmployeeNumber) 性別(Gender)  年齡(Age) 是否為成年人(Over18)  \
# 0                        1     Female       41              Y
# 1                        2       Male       49              Y
# 2                        4       Male       37              Y
# 3                        5     Female       33              Y
# 4                        7       Male       27              Y
# ...                    ...        ...      ...            ...
# 1465                  2061       Male       36              Y
# 1466                  2062       Male       39              Y
# 1467                  2064       Male       27              Y
# 1468                  2065       Male       49              Y
# 1469                  2068       Male       34              Y
#
#      婚姻狀態(MaritalStatus)  通勤距離(DistanceFromHome)  教育程度(Education)  \
# 0                 Single                       1                2
# ...

# %%
# Or, create an empty Series with a specified dtype:
df = pd.Series(dtype=object)

# Or, create a Series from data:
data = [1, 2, 3]
df = pd.Series(data, index=['a', 'b', 'c'])

df
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
df['b']
# Out:
# 2

# %%
df = pd.Series([170,180,160],
        index = ['Bob','John','Mary'],
        name = '身高')
df
# Out:
# Bob     170
# John    180
# Mary    160
# Name: 身高, dtype: int64

# %%
df['Mary']
# Out:
# 160

# %%
df.iloc[2]
# Out:
# 160

# %%
population = {'china':2156484,'japan':654221,'taiwan':1233, 'w':6644}
df = pd.Series(population, name = '人口')
df
# Out:
# china     2156484
# japan      654221
# taiwan       1233
# w            6644
# Name: 人口, dtype: int64

# %%
df.iloc[1:2]
# Out:
# japan    654221
# Name: 人口, dtype: int64

# %%
pd.Series([2,4,6,8])
# Out:
# 0    2
# 1    4
# 2    6
# 3    8
# dtype: int64

# %%
df.index
# Out:
# Index(['china', 'japan', 'taiwan', 'w'], dtype='object')

# %%
df.name
# Out:
# '人口'

# %%
height = pd.Series([170,180,160],
        index = ['Bob','John','Mary'],
        name = '身高')
weight = pd.Series([60,70,80],
        index = ['Bob','John','Mary'],
        name = '體重')
df = pd.DataFrame({'身高':height,'體重':weight})
df
# Out:
#        身高  體重
# Bob   170  60
# John  180  70
# Mary  160  80

# %%
'Bob' in df
# Out:
# False

# %%
'Bob' in df.index
# Out:
# True

# %%
'體重' in df.columns
# Out:
# True

# %%
df['體重']
# Out:
# Bob     60
# John    70
# Mary    80
# Name: 體重, dtype: int64

# %%
iris = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.iloc[2:6]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa

# %%
df.體重/(df.身高/100)**2
# Out:
# Bob     20.761246
# John    21.604938
# Mary    31.250000
# dtype: float64

# %%
df['bmi'] = df['體重']/(df['身高']/100)**2
df
# Out:
#        身高  體重        bmi
# Bob   170  60  20.761246
# John  180  70  21.604938
# Mary  160  80  31.250000

# %%
df['身高'] >= 170
# Out:
# Bob      True
# John     True
# Mary    False
# Name: 身高, dtype: bool

# %%
df[ df['身高'] >= 170 ]['bmi']
# Out:
# Bob     20.761246
# John    21.604938
# Name: bmi, dtype: float64

# %%
df[ df['bmi'] >= 24 ].index
# Out:
# Index(['Mary'], dtype='object')

# %%
df.describe()
# Out:
#           身高    體重        bmi
# count    3.0   3.0   3.000000
# mean   170.0  70.0  24.538728
# std     10.0  10.0   5.827421
# min    160.0  60.0  20.761246
# 25%    165.0  65.0  21.183092
# 50%    170.0  70.0  21.604938
# 75%    175.0  75.0  26.427469
# max    180.0  80.0  31.250000

# %%
df.sort_values('bmi')
# Out:
#        身高  體重        bmi
# Bob   170  60  20.761246
# John  180  70  21.604938
# Mary  160  80  31.250000

# %%
df['身高'].unique()
# Out:
# array([170, 180, 160])

# %%
df.shape
# Out:
# (3, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, Bob to Mary
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   身高      3 non-null      int64
#  1   體重      3 non-null      int64
#  2   bmi     3 non-null      float64
# dtypes: float64(1), int64(2)
# memory usage: 204.0+ bytes

# %%
df.isnull().sum()
# Out:
# 身高     0
# 體重     0
# bmi    0
# dtype: int64
