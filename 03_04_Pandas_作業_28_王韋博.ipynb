# %% [markdown]
# <a href="https://colab.research.google.com/github/t8101349/Colab-/blob/master/03_04_Pandas_%E4%BD%9C%E6%A5%AD_28_%E7%8E%8B%E9%9F%8B%E5%8D%9A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 作業
# * 完成後請寄到EMAIL : clement.class.02@gmail.com
# * 信件主旨請設定為： 03-04.Pandas_作業_學號_姓名  (例: "03-04.Pandas_作業_00_陳仁政")
# * 附件檔名請設定為： 03-04.Pandas_作業_學號_姓名.ipynb (例: "03-04.Pandas_作業_00_陳仁政.ipynb")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
data = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/R公司_人員資料.xlsx')
data
# Out:
#       員工編號(EmployeeNumber) 性別(Gender)  年齡(Age) 是否為成年人(Over18)  \
# 0                        1     Female       41              Y
# 1                        2       Male       49              Y
# 2                        4       Male       37              Y
# 3                        5     Female       33              Y
# 4                        7       Male       27              Y
# ...                    ...        ...      ...            ...
# 1465                  2061       Male       36              Y
# 1466                  2062       Male       39              Y
# 1467                  2064       Male       27              Y
# 1468                  2065       Male       49              Y
# 1469                  2068       Male       34              Y
#
#      婚姻狀態(MaritalStatus)  通勤距離(DistanceFromHome)  教育程度(Education)  \
# 0                 Single                       1                2
# 1                Married                       8                1
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 34 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   員工編號(EmployeeNumber)               1470 non-null   int64
#  1   性別(Gender)                         1470 non-null   object
#  2   年齡(Age)                            1470 non-null   int64
#  3   是否為成年人(Over18)                     1470 non-null   object
#  4   婚姻狀態(MaritalStatus)                1470 non-null   object
#  5   通勤距離(DistanceFromHome)             1470 non-null   int64
#  6   教育程度(Education)                    1470 non-null   int64
#  7   教育專業領域(EducationField)             1470 non-null   object
#  8   部門(Department)                     1470 non-null   object
#  9   職位名稱(JobRole)                      1470 non-null   object
#  10  職位等級(JobLevel)                     1470 non-null   int64
# ...

# %%
data.columns
# Out:
# Index(['員工編號(EmployeeNumber)', '性別(Gender)', '年齡(Age)', '是否為成年人(Over18)',
#        '婚姻狀態(MaritalStatus)', '通勤距離(DistanceFromHome)', '教育程度(Education)',
#        '教育專業領域(EducationField)', '部門(Department)', '職位名稱(JobRole)',
#        '職位等級(JobLevel)', '在該公司工作總年資(YearsAtCompany)',
#        '在該職位工作年資(YearsInCurrentRole)', '在該職等工作年資(YearsSinceLastPromotion)',
#        '與現任管理者工作年資(YearsWithCurrManager)', '總工作年資(TotalWorkingYears)',
#        '過去工作公司家數(NumCompaniesWorked)', '每日工資額(DailyRate)',
#        '每小時工資額(HourlyRate)', '月收入(MonthlyIncome)', '月費率(MonthlyRate)',
#        '標準工作時間(StandardHours)', '加班(OverTime)', '調薪百分比(PercentSalaryHike)',
#        '股票選擇權等級(StockOptionLevel)', '績效評估(PerformanceRating)',
#        '出差頻率(BusinessTravel)', '去年訓練時間(TrainingTimesLastYear)',
#        '工作滿意度(JobSatisfaction)', '工作環境滿意度(EnvironmentSatisfaction)',
#        '工作投入(JobInvolvement)', '工作生活平衡(WorkLifeBalance)',
#        '人際關係滿意度(RelationshipSatisfaction)', '離職(Attrition)'],
#       dtype='object')

# %%
data.describe()
# Out:
#        員工編號(EmployeeNumber)      年齡(Age)  通勤距離(DistanceFromHome)  \
# count           1470.000000  1470.000000             1470.000000
# mean            1024.865306    36.923810                9.192517
# std              602.024335     9.135373                8.106864
# min                1.000000    18.000000                1.000000
# 25%              491.250000    30.000000                2.000000
# 50%             1020.500000    36.000000                7.000000
# 75%             1555.750000    43.000000               14.000000
# max             2068.000000    60.000000               29.000000
#
#        教育程度(Education)  職位等級(JobLevel)  在該公司工作總年資(YearsAtCompany)  \
# count      1470.000000     1470.000000                1470.000000
# mean          2.912925        2.063946                   7.008163
# std           1.024165        1.106940                   6.126525
# min           1.000000        1.000000                   0.000000
# ...

# %%
# 請列出 離職 這個欄位的資料
data['離職(Attrition)']
# Out:
# 0       Yes
# 1        No
# 2       Yes
# 3        No
# 4        No
#        ...
# 1465     No
# 1466     No
# 1467     No
# 1468     No
# 1469     No
# Name: 離職(Attrition), Length: 1470, dtype: object

# %%
# 請查詢並列出 已經離職 的員工
is_Attrition = data['離職(Attrition)'] == 'Yes'
data[is_Attrition]
# Out:
#       員工編號(EmployeeNumber) 性別(Gender)  年齡(Age) 是否為成年人(Over18)  \
# 0                        1     Female       41              Y
# 2                        4       Male       37              Y
# 14                      19       Male       28              Y
# 21                      27       Male       36              Y
# 24                      31       Male       34              Y
# ...                    ...        ...      ...            ...
# 1438                  2023       Male       23              Y
# 1442                  2027       Male       29              Y
# 1444                  2032       Male       56              Y
# 1452                  2044       Male       50              Y
# 1461                  2055       Male       50              Y
#
#      婚姻狀態(MaritalStatus)  通勤距離(DistanceFromHome)  教育程度(Education)  \
# 0                 Single                       1                2
# 2                 Single                       2                2
# ...

# %%
# 請增加一個新的欄位 離職_數值
# 並分別用 0 跟 1 來表示這個員工是否離職
data['離職_數值'] = data['離職(Attrition)'].map({'Yes': 1, 'No': 0})
data
# Out:
#       員工編號(EmployeeNumber) 性別(Gender)  年齡(Age) 是否為成年人(Over18)  \
# 0                        1     Female       41              Y
# 1                        2       Male       49              Y
# 2                        4       Male       37              Y
# 3                        5     Female       33              Y
# 4                        7       Male       27              Y
# ...                    ...        ...      ...            ...
# 1465                  2061       Male       36              Y
# 1466                  2062       Male       39              Y
# 1467                  2064       Male       27              Y
# 1468                  2065       Male       49              Y
# 1469                  2068       Male       34              Y
#
#      婚姻狀態(MaritalStatus)  通勤距離(DistanceFromHome)  教育程度(Education)  \
# 0                 Single                       1                2
# 1                Married                       8                1
# ...

# %%
# 請計算 加班 是否會影響的離職率
#data[['加班(OverTime)','離職(Attrition)']]
#data['離職(Attrition)'] = data['離職(Attrition)'].replace('Yes', 1)
#data['離職(Attrition)'] = data['離職(Attrition)'].replace('No', 0)
#data['加班(OverTime)'] = data['加班(OverTime)'].replace('Yes', 1)
#data['加班(OverTime)'] = data['加班(OverTime)'].replace('No', 0)
OverTime_group = data.groupby('加班(OverTime)')['離職_數值']
OverTime_stats = OverTime_group.agg(total='size', left='sum').reset_index()

OverTime_stats['離職率(Attrition Rate)'] = OverTime_stats['left'] / OverTime_stats['total']
OverTime_stats
# Out:
#   加班(OverTime)  total  left  離職率(Attrition Rate)
# 0           No   1054   110             0.104364
# 1          Yes    416   127             0.305288

# %%
# 請計算 教育程度 是否會影響的離職率
# data[['教育程度(Education)','離職(Attrition)']]

Education_group = data.groupby('教育程度(Education)')['離職_數值']
Education_stats = Education_group.agg(total='size', left='sum').reset_index()

Education_stats['離職率(Attrition Rate)'] = Education_stats['left'] / Education_stats['total']
Education_stats
# Out:
#    教育程度(Education)  total  left  離職率(Attrition Rate)
# 0                1    170    31             0.182353
# 1                2    282    44             0.156028
# 2                3    572    99             0.173077
# 3                4    398    58             0.145729
# 4                5     48     5             0.104167

# %%
# 請計算 各部門 的離職率
# 可使用 GroupBy
# Department = data.groupby(['部門(Department)','離職(Attrition)'])
# Department['離職(Attrition)'].size() / Department['部門(Department)'].size()
Department_group = data.groupby('部門(Department)')['離職_數值']
Department_stats = Department_group.agg(total='size', left='sum').reset_index()

Department_stats['離職率(Attrition Rate)'] = Department_stats['left'] / Department_stats['total']
Department_stats
# Out:
#            部門(Department)  total  left  離職率(Attrition Rate)
# 0         Human Resources     63    12             0.190476
# 1  Research & Development    961   133             0.138398
# 2                   Sales    446    92             0.206278

# %%
# 請找出哪個職位的離職率最高？  ans: Sales
Department_stats.sort_values(by='離職率(Attrition Rate)', ascending=False).head(1)
# Out:
#   部門(Department)  total  left  離職率(Attrition Rate)
# 2          Sales    446    92             0.206278

# %%
# 請找出教育程度跟月收入之間是否有關係？ ans:與個體月收入無關 與平均月收入有關
#月收入(MonthlyIncome) 教育程度(Education)
Education_Income_group = data.groupby('教育程度(Education)')['月收入(MonthlyIncome)'].mean().reset_index(name = 'mean_income')
Education_Income_group
# Out:
#    教育程度(Education)  mean_income
# 0                1  5640.570588
# 1                2  6226.645390
# 2                3  6517.263986
# 3                4  6832.402010
# 4                5  8277.645833

# %%
import seaborn as sns
import matplotlib.pyplot as plt


sns.barplot(data=Education_Income_group, x='教育程度(Education)', y='mean_income', color='skyblue')
plt.title('Mean Monthly Income With Different Education')
plt.xlabel('Education')
plt.ylabel('Mean Monthly Income')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.catplot(data=data, x='教育程度(Education)', y='月收入(MonthlyIncome)', color='skyblue',kind='violin')
plt.title('Monthly Income With Different Education')
plt.xlabel('Education')
plt.ylabel('Monthly Income')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/axisgrid.py:123: UserWarning: Glyph 25945 (\N{CJK UNIFIED IDEOGRAPH-6559}) missing from font(s) DejaVu Sans.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/seaborn/axisgrid.py:123: UserWarning: Glyph 32946 (\N{CJK UNIFIED IDEOGRAPH-80B2}) missing from font(s) DejaVu Sans.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/seaborn/axisgrid.py:123: UserWarning: Glyph 31243 (\N{CJK UNIFIED IDEOGRAPH-7A0B}) missing from font(s) DejaVu Sans.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/seaborn/axisgrid.py:123: UserWarning: Glyph 24230 (\N{CJK UNIFIED IDEOGRAPH-5EA6}) missing from font(s) DejaVu Sans.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/seaborn/axisgrid.py:123: UserWarning: Glyph 26376 (\N{CJK UNIFIED IDEOGRAPH-6708}) missing from font(s) DejaVu Sans.
# ...

# %%
print('相關性係數=', data['教育程度(Education)'].corr(data['月收入(MonthlyIncome)']))
print('相關性係數=', Education_Income_group['教育程度(Education)'].corr(Education_Income_group['mean_income']))
# Out:
# 相關性係數= 0.09496067704188886
# 相關性係數= 0.9431921088744608

# %%
# 請計算各個部門的人力支出總額跟占比，並畫出派餅圖
# matplotlib.pyplot.pie
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.pie.html
import matplotlib.pyplot as plt
Department_salary_group = data.groupby('部門(Department)')['月收入(MonthlyIncome)']
Department_salary_stats = Department_salary_group.agg(Department_total='sum').reset_index()
print(Department_salary_stats)
#Department_salary_stats['total'] = Department_salary_group['Department_total'].sum().reset_index()


# Get the department names for labels
labels = [f"{row['部門(Department)']}: {row['Department_total']}"
          for _, row in Department_salary_stats.iterrows()]
plt.pie(x='Department_total', data=Department_salary_stats, labels=labels,
        pctdistance=0.6, labeldistance=1.1, startangle=0, radius=1)
plt.show()


total_salary = Department_salary_stats['Department_total'].sum()
labels2 = [f"{row['部門(Department)']}: {row['Department_total']} ({(row['Department_total'] / total_salary) * 100:.1f}%)"
          for _, row in Department_salary_stats.iterrows()]
plt.pie(x='Department_total', data=Department_salary_stats, labels=labels2,
        pctdistance=0.6, labeldistance=1.1, startangle=0, radius=1)
plt.show()
# Out:
#            部門(Department)  Department_total
# 0         Human Resources            419234
# 1  Research & Development           6036284
# 2                   Sales           3103791

# %%
# 請計算各部門的現職員工總數
# 並用長條圖顯示
# matplotlib.pyplot.bar
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html
import matplotlib.pyplot as plt
Department_group = data.groupby('部門(Department)')['離職_數值']
Department_stats = Department_group.agg(total='size', left='sum').reset_index()
Department_stats['now'] = Department_stats['total'] - Department_stats['left']

plt.bar(x = '部門(Department)', height = 'now', width=0.5, data=Department_stats, label='now')
# Out:
# <BarContainer object of 3 artists>
