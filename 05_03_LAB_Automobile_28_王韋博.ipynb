# %% [markdown]
# <a href="https://colab.research.google.com/github/t8101349/Colab-/blob/master/05_03_LAB_Automobile_28_%E7%8E%8B%E9%9F%8B%E5%8D%9A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# * 完成後請寄到EMAIL : clement.class.02@gmail.com
# * 信件主旨請設定為： 05-03.LAB_Automobile_學號_姓名  (例: "05-03.LAB_Automobile_00_陳仁政")
# * 附件檔名請設定為： 05-03.LAB_Automobile_學號_姓名.ipynb (例: "05-03.LAB_Automobile_00_陳仁政.ipynb")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Automobile.csv")
data.head(10)
# Out:
#    symboling  Normalized-losses         make Fuel-type aspiration  \
# 0          3                NaN  alfa-romero       gas        std
# 1          3                NaN  alfa-romero       gas        std
# 2          1                NaN  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
# 5          2                NaN         audi       gas        std
# 6          1              158.0         audi       gas        std
# 7          1                NaN         audi       gas        std
# 8          1              158.0         audi       gas      turbo
# 9          0                NaN         audi       gas      turbo
#
#   Num-of-doors   Body-style Drive-wheels Engine-location  Wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# ...

# %%
#查看資料筆數跟欄位數目
data.shape
# Out:
# (205, 26)

# %%
# 檢查資料欄位的型態，以及缺失狀況
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   Normalized-losses  164 non-null    float64
#  2   make               205 non-null    object
#  3   Fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   Num-of-doors       203 non-null    object
#  6   Body-style         205 non-null    object
#  7   Drive-wheels       205 non-null    object
#  8   Engine-location    205 non-null    object
#  9   Wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  Curb-weight        205 non-null    int64
#  14  Engine-type        205 non-null    object
#  15  Num-of-cylinders   205 non-null    object
# ...

# %%
# 計算各欄位資料缺失狀況
data.isnull().sum()
# Out:
# symboling             0
# Normalized-losses    41
# make                  0
# Fuel-type             0
# aspiration            0
# Num-of-doors          2
# Body-style            0
# Drive-wheels          0
# Engine-location       0
# Wheel-base            0
# length                0
# width                 0
# height                0
# Curb-weight           0
# Engine-type           0
# Num-of-cylinders      0
# Engine-size           0
# Fuel-system           0
# bore                  4
# stroke                4
# Compression-ratio     0
# horsepower            2
# Peak-rpm              2
# City-mpg              0
# Highway-mpg           0
# price                 4
# dtype: int64

# %%
# 查看一下資料的基本統計值
data.describe(include='all')
# Out:
#          symboling  Normalized-losses    make Fuel-type aspiration  \
# count   205.000000         164.000000     205       205        205
# unique         NaN                NaN      22         2          2
# top            NaN                NaN  toyota       gas        std
# freq           NaN                NaN      32       185        168
# mean      0.834146         122.000000     NaN       NaN        NaN
# std       1.245307          35.442168     NaN       NaN        NaN
# min      -2.000000          65.000000     NaN       NaN        NaN
# 25%       0.000000          94.000000     NaN       NaN        NaN
# 50%       1.000000         115.000000     NaN       NaN        NaN
# 75%       2.000000         150.000000     NaN       NaN        NaN
# max       3.000000         256.000000     NaN       NaN        NaN
#
#        Num-of-doors Body-style Drive-wheels Engine-location  Wheel-base  ...  \
# count           203        205          205             205  205.000000  ...
# ...

# %%
# 那一個廠牌的車子數量最多？
#方法一
# data.groupby('make')['make'].count().sort_values(ascending=False)

data.groupby('make')['make'].size().sort_values(ascending=False)
# Out:
# make
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# volkswagen       12
# subaru           12
# peugot           11
# volvo            11
# dodge             9
# mercedes-benz     8
# bmw               8
# audi              7
# plymouth          7
# saab              6
# porsche           5
# isuzu             4
# jaguar            3
# chevrolet         3
# alfa-romero       3
# renault           2
# mercury           1
# Name: make, dtype: int64

# %%
data['make'].value_counts() # 方法二
# Out:
# make
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# volkswagen       12
# subaru           12
# peugot           11
# volvo            11
# dodge             9
# mercedes-benz     8
# bmw               8
# audi              7
# plymouth          7
# saab              6
# porsche           5
# isuzu             4
# jaguar            3
# chevrolet         3
# alfa-romero       3
# renault           2
# mercury           1
# Name: count, dtype: int64

# %%
# 練習題
# 哪一種車型(Body-style)的數量最多？
data['Body-style'].value_counts().head(1)
# Out:
# Body-style
# sedan    96
# Name: count, dtype: int64

# %% [markdown]
# # Label vs Number

# %%
# 畫出不同燃油型態Fuel-type的價格分布
sns.catplot(x="Fuel-type", y="price", kind="swarm", data=data)

# %%
sns.catplot(x="Fuel-type", y="price", kind="violin", data=data)

# %%
sns.catplot(data, x="Body-style", y="Engine-size", kind="swarm", s=8) #方法1
sns.displot(data, x="Engine-size", hue="Body-style", kde=True) #方法2
sns.catplot(data, x="Body-style", y="Engine-size", kind="box") #方法3
sns.catplot(data, x="Body-style", y="Engine-size", kind="boxen") #方法4
sns.catplot(data, x="Body-style", y="Engine-size", kind="violin") #方法5
sns.catplot(data, x="Body-style", y="Engine-size", kind="point") #方法6
# sns.catplot(data, x="Body-style", y="Engine-size", kind="point", hue='Drive-wheels') #方法7
plt.show()

# %%
# 找出引擎位置(Body-style)跟引擎大小(Engine-size)之間有沒有關係？
sns.catplot(x="Body-style", y="Engine-size", kind="bar", data=data)
sns.catplot(x="Body-style", y="Engine-size", kind="box", data=data)

# %%
# 練習題
# 找出廠牌跟價格之間有沒有關係？
sns.catplot(x="make", y="price", kind="bar", data=data)
sns.catplot(x="make", y="price", kind="box", data=data)
sns.catplot(x="make", y="price", kind="point", data=data)

# %%
# 練習題
# 找出Engine-type跟horsepower之間有沒有關係？
sns.catplot(x="Engine-type", y="horsepower", kind="box", data=data)
sns.catplot(x="Engine-type", y="horsepower", kind="point", data=data)

# %% [markdown]
# # Number vs Number

# %%
# 找出引擎大小(Engine-size)跟馬力(horsepower)之間有沒有關係？
sns.relplot(data, x="Engine-size", y="horsepower") #方法1
plt.show()
sns.regplot(data, x="Engine-size", y="horsepower") #方法2
plt.show()
sns.lmplot(data, x="Engine-size", y="horsepower") #方法3
plt.show()

# %%
# 計算引擎大小(Engine-size)跟馬力(horsepower)之間相關性係數
print('相關性係數=', data['Engine-size'].corr(data['horsepower']))
print('相關性係數矩陣=', data[['Engine-size', 'horsepower']].corr()) # 方法2
# Out:
# 相關性係數= 0.8107725559959597
# 相關性係數矩陣=              Engine-size  horsepower
# Engine-size     1.000000    0.810773
# horsepower      0.810773    1.000000

# %%
# 練習題
# 找出價格跟馬力之間有沒有關係？
sns.relplot(data, x="price", y="horsepower")
plt.show()
sns.regplot(data, x="price", y="horsepower")
plt.show()
print('相關性係數=', data['price'].corr(data['horsepower']))
# Out:
# 相關性係數= 0.8105330821322059

# %%
# 練習題
# 找出價格跟車長之間有沒有關係？
sns.relplot(data, x="price", y="length")
plt.show()
sns.regplot(data, x="price", y="length")
plt.show()
print('相關性係數=', data['price'].corr(data['length']))
# Out:
# 相關性係數= 0.6906283804483649

# %% [markdown]
# # Label vs Label

# %%
# 找出Body-style跟Num-of-doors的關係
sns.displot(data,x='Body-style', hue='Num-of-doors') #方法1
sns.displot(data,x='Body-style', hue='Num-of-doors', multiple="dodge") #方法2
sns.displot(data,x='Body-style', hue='Num-of-doors', multiple="dodge", stat="density") #方法3

plt.show()

# %%
# 計算Body-style跟Num-of-doors的計數矩陣
data.groupby(['Body-style','Num-of-doors']).size().unstack(fill_value=0)
# Out:
# Num-of-doors  four  two
# Body-style
# convertible      0    6
# hardtop          0    8
# hatchback       10   60
# sedan           79   15
# wagon           25    0

# %%
data.groupby(['Body-style','Num-of-doors']).size().reset_index(name='count')
# Out:
#     Body-style Num-of-doors  count
# 0  convertible          two      6
# 1      hardtop          two      8
# 2    hatchback         four     10
# 3    hatchback          two     60
# 4        sedan         four     79
# 5        sedan          two     15
# 6        wagon         four     25

# %%
# 畫出上個表格的熱圖

matrix = data.groupby(['Body-style','Num-of-doors']).size().unstack(fill_value=0)
sns.heatmap(matrix, annot=True, cmap='coolwarm', cbar=True)
plt.show()

# %%
# 練習題
# 找出Body-style跟廠牌的關係

Bodystyle_doors = data.groupby(by = ['Body-style','make']).size().unstack(fill_value= 0)

print(Bodystyle_doors)

sns.heatmap(Bodystyle_doors, annot=True, cmap='coolwarm', cbar=True)
# Out:
# make         alfa-romero  audi  bmw  chevrolet  dodge  honda  isuzu  jaguar  \
# Body-style
# convertible            2     0    0          0      0      0      0       0
# hardtop                0     0    0          0      0      0      0       0
# hatchback              1     1    0          2      5      7      1       0
# sedan                  0     5    8          1      3      5      3       3
# wagon                  0     1    0          0      1      1      0       0
#
# make         mazda  mercedes-benz  ...  nissan  peugot  plymouth  porsche  \
# Body-style                         ...
# convertible      0              1  ...       0       0         0        1
# hardtop          0              2  ...       1       0         0        2
# hatchback       10              0  ...       5       0         4        2
# sedan            7              4  ...       9       7         2        0
# wagon            0              1  ...       3       4         1        0
#
# ...

# %% [markdown]
# # Group By

# %%
# 計算不同廠牌汽車的平均價格
data.groupby(['make'])['price'].mean()
# Out:
# make
# alfa-romero      15498.333333
# audi             17859.166667
# bmw              26118.750000
# chevrolet         6007.000000
# dodge             7875.444444
# honda             8184.692308
# isuzu             8916.500000
# jaguar           34600.000000
# mazda            10652.882353
# mercedes-benz    33647.000000
# mercury          16503.000000
# mitsubishi        9239.769231
# nissan           10415.666667
# peugot           15489.090909
# plymouth          7963.428571
# porsche          31400.500000
# renault           9595.000000
# saab             15223.333333
# subaru            8541.250000
# toyota            9885.812500
# volkswagen       10077.500000
# volvo            18063.181818
# Name: price, dtype: float64

# %%
# 計算不同廠牌汽車的平均價格，並畫出來
#方法一
mean_price = data.groupby('make')['price'].mean().reset_index(name='MeanPrice')
ax = sns.barplot(mean_price, x='MeanPrice', y='make')
for index, row in mean_price.iterrows():
    ax.text(row['MeanPrice'] + 1000,  # 偏移量，確保數字不會跟條形重疊
            index,
            round(row['MeanPrice'], 2),  # 顯示價格，保留兩位小數
            color='black',
            ha="left",  # 水平對齊
            va="center")  # 垂直對齊
plt.show()


#方法二
mean_price = data.groupby('make')['price'].mean().reset_index(name='MeanPrice')
bars = plt.barh(mean_price['make'], mean_price['MeanPrice'], color='skyblue')
# 在每個條形上顯示 MeanPrice 的數值
for bar in bars:
    # 使用 bar.get_width() 來獲取每個條形的長度（即價格）
    width = bar.get_width()
    plt.text(width + 1000,  # 偏移量，確保數字不會跟條形重疊
             bar.get_y() + bar.get_height() / 2,  # 垂直位置
             f'{width:.2f}',  # 顯示價格，保留兩位小數
             color='black',
             va='center')  # 垂直對齊

# 顯示圖表
plt.xlabel('Mean Price')
plt.ylabel('Make')
plt.title('Mean Price by Make')
plt.show()

# %%
# 練習題
# 修改上圖將平均價格由高到低排序
mean_price = data.groupby('make')['price'].mean().reset_index(name='MeanPrice')
mean_price = mean_price.sort_values(by='MeanPrice', ascending=False).reset_index(drop=True)
print(mean_price)
mean_price_order = mean_price.make
bars = sns.barplot(mean_price, x='MeanPrice', y='make', order=mean_price_order)
for index, row in mean_price.iterrows():
  bars.text(row['MeanPrice'] + 1000,  # 偏移量，確保數字不會跟條形重疊
            index,
            round(row['MeanPrice'], 2),  # 顯示價格，保留兩位小數
            color='black',
            ha="left",  # 水平對齊
            va="center")  # 垂直對齊
plt.show()
# Out:
#              make     MeanPrice
# 0          jaguar  34600.000000
# 1   mercedes-benz  33647.000000
# 2         porsche  31400.500000
# 3             bmw  26118.750000
# 4           volvo  18063.181818
# 5            audi  17859.166667
# 6         mercury  16503.000000
# 7     alfa-romero  15498.333333
# 8          peugot  15489.090909
# 9            saab  15223.333333
# 10          mazda  10652.882353
# 11         nissan  10415.666667
# 12     volkswagen  10077.500000
# 13         toyota   9885.812500
# 14        renault   9595.000000
# 15     mitsubishi   9239.769231
# 16          isuzu   8916.500000
# 17         subaru   8541.250000
# 18          honda   8184.692308
# 19       plymouth   7963.428571
# 20          dodge   7875.444444
# 21      chevrolet   6007.000000

# %%
# 練習題
# 計算不同車型的平均馬力
Mean_horsepower = data.groupby('Body-style')['horsepower'].mean().reset_index(name='Meanhorsepower')
Mean_horsepower = Mean_horsepower.sort_values(by='Meanhorsepower', ascending=False).reset_index(drop=True)
print(Mean_horsepower)
# 觀察
sns.catplot(x="Body-style", y="horsepower", kind="box", data=data)
# Out:
#     Body-style  Meanhorsepower
# 0      hardtop      142.250000
# 1  convertible      131.666667
# 2        sedan      103.104167
# 3    hatchback      101.333333
# 4        wagon       97.750000

# %%
# 練習題
# 找出車長與車種之間是否有關係？
Mean_length = data.groupby('Body-style')['length'].mean().reset_index(name='Meanlength')
print(Mean_length)
# 觀察
sns.catplot(x="Body-style", y="length", kind="box", data=data)
# Out:
#     Body-style  Meanlength
# 0  convertible  170.383333
# 1      hardtop  176.937500
# 2    hatchback  166.592857
# 3        sedan  177.585417
# 4        wagon  181.304000

# %%
# 練習題
# 找出不同車廠對於生產車子Body-style是否有偏好？
Bodystyle_make = data.groupby(['Body-style','make']).size().unstack(fill_value=0)

# 觀察
sns.heatmap(Bodystyle_make, annot=True, cmap='coolwarm', cbar=True)
# Out:
# <Axes: xlabel='make', ylabel='Body-style'>

# %%
# 練習題
# 找出Body-style是否會影響車價？
Mean_price = data.groupby('Body-style')['price'].mean().reset_index(name='MeanPrice')
print(Mean_price)
# 觀察
sns.catplot(x="Body-style", y="price", kind="box", data=data)
# Out:
#     Body-style     MeanPrice
# 0  convertible  21890.500000
# 1      hardtop  22208.500000
# 2    hatchback   9957.441176
# 3        sedan  14459.755319
# 4        wagon  12371.960000

# %%
# 練習題
# 找出最高時速油耗Highway-mpg跟馬力horsepower之間是否有關係？
sns.regplot(data, x="Highway-mpg", y="horsepower")
plt.show()

# %%
# Highway-mpg跟horsepower之間是否有關係
print('Highway-mpg相關性係數=', data['Highway-mpg'].corr(data['horsepower']))
# Peak-rpm跟horsepower之間是否有關係
print('Peak-rpm相關性係數=', data['Peak-rpm'].corr(data['horsepower']))
# Out:
# Highway-mpg相關性係數= -0.7709076931171815
# Peak-rpm相關性係數= 0.13097080454313337

# %%
# 練習題
# 根據 車廠與車型(Body-style)的不同，計算各個組合的平均價格
Bodystyle_make_meanprice = data.groupby(['Body-style','make'])['price'].mean().reset_index(name='MeanPrice')
print(Bodystyle_make_meanprice)
# Out:
#      Body-style           make     MeanPrice
# 0   convertible    alfa-romero  14997.500000
# 1   convertible  mercedes-benz  35056.000000
# 2   convertible        porsche  37028.000000
# 3   convertible         toyota  17669.000000
# 4   convertible     volkswagen  11595.000000
# 5       hardtop  mercedes-benz  36788.000000
# 6       hardtop         nissan   8249.000000
# 7       hardtop        porsche  33278.000000
# 8       hardtop         toyota   9762.333333
# 9     hatchback    alfa-romero  16500.000000
# 10    hatchback           audi           NaN
# 11    hatchback      chevrolet   5723.000000
# 12    hatchback          dodge   7819.800000
# 13    hatchback          honda   7054.428571
# 14    hatchback          isuzu  11048.000000
# 15    hatchback          mazda  10085.000000
# 16    hatchback        mercury  16503.000000
# 17    hatchback     mitsubishi   9597.888889
# 18    hatchback         nissan  14409.000000
# 19    hatchback       plymouth   8130.500000
# ...
